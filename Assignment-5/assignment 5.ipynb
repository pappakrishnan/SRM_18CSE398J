# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv('bill_authentication.csv')
df.head()
# Out:
#    Variance  Skewness  Curtosis  Entropy  Class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %%
df["Class"].value_counts()
# Out:
# 0    762
# 1    610
# Name: Class, dtype: int64

# %%
X = df.iloc[:, 1:-1].values
y = df.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.33, random_state=42)

# %%
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
DT=DecisionTreeClassifier()
DT.fit(X_train,y_train)
predict=DT.predict(X_test)

# %%
plt.figure(figsize=(15,10))
feature_names=['Variance','Skewness','Curtosis','Entropy']
tree.plot_tree(DT,feature_names=feature_names,filled=True)
# Out:
# [Text(478.65099158653845, 520.95, 'Variance <= 5.161\ngini = 0.495\nsamples = 919\nvalue = [505, 414]'),
#  Text(198.10006009615384, 475.65000000000003, 'Skewness <= -0.027\ngini = 0.473\nsamples = 629\nvalue = [242, 387]'),
#  Text(69.75, 430.35, 'Curtosis <= 0.851\ngini = 0.121\nsamples = 185\nvalue = [12, 173]'),
#  Text(42.92307692307692, 385.05, 'Curtosis <= 0.266\ngini = 0.045\nsamples = 172\nvalue = [4, 168]'),
#  Text(21.46153846153846, 339.75, 'Variance <= 4.319\ngini = 0.013\nsamples = 150\nvalue = [1, 149]'),
#  Text(10.73076923076923, 294.45, 'gini = 0.0\nsamples = 137\nvalue = [0, 137]'),
#  Text(32.19230769230769, 294.45, 'Curtosis <= -2.494\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(21.46153846153846, 249.14999999999998, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(42.92307692307692, 249.14999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(64.38461538461539, 339.75, 'Variance <= 2.126\ngini = 0.236\nsamples = 22\nvalue = [3, 19]'),
#  Text(53.653846153846146, 294.45, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(75.11538461538461, 294.45, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(96.57692307692307, 385.05, 'Variance <= 0.87\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(85.84615384615384, 339.75, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(107.30769230769229, 339.75, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(326.4501201923077, 430.35, 'Variance <= -5.122\ngini = 0.499\nsamples = 444\nvalue = [230, 214]'),
#  Text(139.5, 385.05, 'Variance <= -6.946\ngini = 0.173\nsamples = 136\nvalue = [13, 123]'),
#  Text(128.76923076923077, 339.75, 'gini = 0.0\nsamples = 76\nvalue = [0, 76]'),
#  Text(150.23076923076923, 339.75, 'Curtosis <= -1.203\ngini = 0.339\nsamples = 60\nvalue = [13, 47]'),
#  Text(139.5, 294.45, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(160.96153846153845, 294.45, 'Skewness <= 6.408\ngini = 0.249\nsamples = 55\nvalue = [8, 47]'),
#  Text(150.23076923076923, 249.14999999999998, 'gini = 0.0\nsamples = 29\nvalue = [0, 29]'),
#  Text(171.69230769230768, 249.14999999999998, 'Skewness <= 8.558\ngini = 0.426\nsamples = 26\nvalue = [8, 18]'),
#  Text(160.96153846153845, 203.84999999999997, 'Curtosis <= 0.641\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(150.23076923076923, 158.55, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(171.69230769230768, 158.55, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(182.4230769230769, 203.84999999999997, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(513.4002403846154, 385.05, 'Skewness <= 3.052\ngini = 0.416\nsamples = 308\nvalue = [217, 91]'),
#  Text(415.1466346153846, 339.75, 'Variance <= 0.461\ngini = 0.478\nsamples = 208\nvalue = [126, 82]'),
#  Text(304.4855769230769, 294.45, 'Variance <= -2.285\ngini = 0.487\nsamples = 110\nvalue = [46, 64]'),
#  Text(225.34615384615384, 249.14999999999998, 'Variance <= -3.889\ngini = 0.298\nsamples = 33\nvalue = [27, 6]'),
#  Text(203.88461538461536, 203.84999999999997, 'Curtosis <= 0.409\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(193.15384615384613, 158.55, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(214.61538461538458, 158.55, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(246.8076923076923, 203.84999999999997, 'Curtosis <= 1.005\ngini = 0.071\nsamples = 27\nvalue = [26, 1]'),
#  Text(236.07692307692307, 158.55, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(257.53846153846155, 158.55, 'Curtosis <= 1.15\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(246.8076923076923, 113.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(268.2692307692308, 113.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(383.62499999999994, 249.14999999999998, 'Variance <= -0.084\ngini = 0.372\nsamples = 77\nvalue = [19, 58]'),
#  Text(332.65384615384613, 203.84999999999997, 'Skewness <= 0.665\ngini = 0.201\nsamples = 53\nvalue = [6, 47]'),
#  Text(300.46153846153845, 158.55, 'Variance <= -0.334\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(289.7307692307692, 113.25, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(311.1923076923077, 113.25, 'Curtosis <= 0.48\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(300.46153846153845, 67.94999999999999, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(321.9230769230769, 67.94999999999999, 'Skewness <= 0.237\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(311.1923076923077, 22.649999999999977, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(332.65384615384613, 22.649999999999977, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(364.8461538461538, 158.55, 'Curtosis <= -0.042\ngini = 0.045\nsamples = 43\nvalue = [1, 42]'),
#  Text(354.1153846153846, 113.25, 'Curtosis <= -0.135\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(343.38461538461536, 67.94999999999999, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(364.8461538461538, 67.94999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(375.57692307692304, 113.25, 'gini = 0.0\nsamples = 40\nvalue = [0, 40]'),
#  Text(434.5961538461538, 203.84999999999997, 'Curtosis <= 0.203\ngini = 0.497\nsamples = 24\nvalue = [13, 11]'),
#  Text(407.7692307692307, 158.55, 'Curtosis <= -0.51\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(397.0384615384615, 113.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(418.49999999999994, 113.25, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(461.4230769230769, 158.55, 'Curtosis <= 1.314\ngini = 0.337\nsamples = 14\nvalue = [11, 3]'),
#  Text(439.96153846153845, 113.25, 'Skewness <= 1.599\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(429.23076923076917, 67.94999999999999, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(450.6923076923077, 67.94999999999999, 'Skewness <= 1.919\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(439.96153846153845, 22.649999999999977, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(461.4230769230769, 22.649999999999977, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(482.88461538461536, 113.25, 'Skewness <= 1.459\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(472.15384615384613, 67.94999999999999, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(493.6153846153846, 67.94999999999999, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(525.8076923076923, 294.45, 'Curtosis <= -0.449\ngini = 0.3\nsamples = 98\nvalue = [80, 18]'),
#  Text(515.0769230769231, 249.14999999999998, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(536.5384615384615, 249.14999999999998, 'Curtosis <= -0.214\ngini = 0.07\nsamples = 83\nvalue = [80, 3]'),
#  Text(525.8076923076923, 203.84999999999997, 'Curtosis <= -0.337\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(515.0769230769231, 158.55, 'Skewness <= 0.579\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(504.3461538461538, 113.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(525.8076923076923, 113.25, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(536.5384615384615, 158.55, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(547.2692307692307, 203.84999999999997, 'gini = 0.0\nsamples = 72\nvalue = [72, 0]'),
#  Text(611.6538461538461, 339.75, 'Variance <= -4.513\ngini = 0.164\nsamples = 100\nvalue = [91, 9]'),
#  Text(590.1923076923076, 294.45, 'Curtosis <= -0.149\ngini = 0.457\nsamples = 17\nvalue = [11, 6]'),
#  Text(579.4615384615385, 249.14999999999998, 'Skewness <= 9.509\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(568.7307692307692, 203.84999999999997, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(590.1923076923076, 203.84999999999997, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(600.9230769230769, 249.14999999999998, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(633.1153846153845, 294.45, 'Variance <= -1.051\ngini = 0.07\nsamples = 83\nvalue = [80, 3]'),
#  Text(622.3846153846154, 249.14999999999998, 'Variance <= -1.212\ngini = 0.136\nsamples = 41\nvalue = [38, 3]'),
#  Text(611.6538461538461, 203.84999999999997, 'Variance <= -2.555\ngini = 0.095\nsamples = 40\nvalue = [38, 2]'),
#  Text(590.1923076923076, 158.55, 'Skewness <= 5.78\ngini = 0.053\nsamples = 37\nvalue = [36, 1]'),
#  Text(579.4615384615385, 113.25, 'gini = 0.0\nsamples = 34\nvalue = [34, 0]'),
#  Text(600.9230769230769, 113.25, 'Skewness <= 6.004\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(590.1923076923076, 67.94999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(611.6538461538461, 67.94999999999999, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(633.1153846153845, 158.55, 'Variance <= -1.721\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(622.3846153846154, 113.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(643.8461538461538, 113.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(633.1153846153845, 203.84999999999997, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(643.8461538461538, 249.14999999999998, 'gini = 0.0\nsamples = 42\nvalue = [42, 0]'),
#  Text(759.201923076923, 475.65000000000003, 'Curtosis <= -4.482\ngini = 0.169\nsamples = 290\nvalue = [263, 27]'),
#  Text(724.326923076923, 430.35, 'Variance <= 9.347\ngini = 0.484\nsamples = 61\nvalue = [36, 25]'),
#  Text(686.7692307692307, 385.05, 'Skewness <= -2.07\ngini = 0.198\nsamples = 27\nvalue = [3, 24]'),
#  Text(665.3076923076923, 339.75, 'Variance <= 7.166\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(654.576923076923, 294.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(676.0384615384614, 294.45, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(708.2307692307692, 339.75, 'Skewness <= 1.413\ngini = 0.08\nsamples = 24\nvalue = [1, 23]'),
#  Text(697.5, 294.45, 'gini = 0.0\nsamples = 23\nvalue = [0, 23]'),
#  Text(718.9615384615385, 294.45, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(761.8846153846154, 385.05, 'Variance <= 9.549\ngini = 0.057\nsamples = 34\nvalue = [33, 1]'),
#  Text(751.1538461538461, 339.75, 'Curtosis <= -6.093\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(740.4230769230769, 294.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(761.8846153846154, 294.45, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(772.6153846153845, 339.75, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(794.076923076923, 430.35, 'Skewness <= 0.543\ngini = 0.017\nsamples = 229\nvalue = [227, 2]'),
#  Text(783.3461538461538, 385.05, 'gini = 0.0\nsamples = 186\nvalue = [186, 0]'),
#  Text(804.8076923076923, 385.05, 'Skewness <= 0.557\ngini = 0.089\nsamples = 43\nvalue = [41, 2]'),
#  Text(794.076923076923, 339.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(815.5384615384614, 339.75, 'Skewness <= 0.633\ngini = 0.046\nsamples = 42\nvalue = [41, 1]'),
#  Text(804.8076923076923, 294.45, 'Skewness <= 0.597\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(794.076923076923, 249.14999999999998, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(815.5384615384614, 249.14999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(826.2692307692307, 294.45, 'gini = 0.0\nsamples = 39\nvalue = [39, 0]')]

# %%
path = DT.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# %%
ccp_alphas
# Out:
# array([0.        , 0.00090678, 0.00097933, 0.00103373, 0.00104784,
#        0.00105614, 0.00106223, 0.00106283, 0.00107896, 0.00108089,
#        0.00109504, 0.00145085, 0.00158557, 0.00181357, 0.00193447,
#        0.00199492, 0.0020856 , 0.00217919, 0.00226696, 0.00317045,
#        0.00348205, 0.00362713, 0.00401308, 0.00435515, 0.00476797,
#        0.00495928, 0.00535472, 0.00659978, 0.00669624, 0.00677431,
#        0.00922246, 0.01641536, 0.01905581, 0.02052929, 0.06724796,
#        0.11777495])

# %%
from sklearn.metrics import accuracy_score
accuracy_train,accuracy_test=[],[]
for i in ccp_alphas:
    DT_clf=DecisionTreeClassifier(ccp_alpha=i)
    DT_clf.fit(X_train,y_train)
    y_pred_train=DT_clf.predict(X_train)
    y_pred_test=DT_clf.predict(X_test)
    accuracy_train.append(accuracy_score(y_train,y_pred_train))
    accuracy_test.append(accuracy_score(y_test,y_pred_test))

# %%
import seaborn as sns
sns.set()
plt.figure(figsize=(14,7))
sns.lineplot(y=accuracy_train,x=ccp_alphas,label="Training Accuracy")
sns.lineplot(y=accuracy_test,x=ccp_alphas,label="Testing Accuracy ")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
DT_clf=DecisionTreeClassifier(ccp_alpha=0.006,random_state=42)
DT_clf.fit(X_train,y_train)
y_pred_train=DT_clf.predict(X_train)
y_pred_test=DT_clf.predict(X_test)
print("Training Accuracy=",accuracy_score(y_train,y_pred_train),"\n Testing Accuracy=",accuracy_score(y_test,y_pred_test))
# Out:
# Training Accuracy= 0.941240478781284
#  Testing Accuracy= 0.9028697571743929

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(DT_clf,feature_names=feature_names,filled=True)
# Out:
# [Text(496.0, 509.625, 'Variance <= 5.161\ngini = 0.495\nsamples = 919\nvalue = [505, 414]'),
#  Text(279.0, 441.675, 'Skewness <= -0.027\ngini = 0.473\nsamples = 629\nvalue = [242, 387]'),
#  Text(155.0, 373.725, 'Curtosis <= 0.851\ngini = 0.121\nsamples = 185\nvalue = [12, 173]'),
#  Text(93.0, 305.775, 'gini = 0.045\nsamples = 172\nvalue = [4, 168]'),
#  Text(217.0, 305.775, 'Variance <= 0.87\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(155.0, 237.825, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(279.0, 237.825, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(403.0, 373.725, 'Variance <= -5.122\ngini = 0.499\nsamples = 444\nvalue = [230, 214]'),
#  Text(341.0, 305.775, 'gini = 0.173\nsamples = 136\nvalue = [13, 123]'),
#  Text(465.0, 305.775, 'Skewness <= 3.052\ngini = 0.416\nsamples = 308\nvalue = [217, 91]'),
#  Text(403.0, 237.825, 'Variance <= 0.461\ngini = 0.478\nsamples = 208\nvalue = [126, 82]'),
#  Text(248.0, 169.875, 'Variance <= -2.285\ngini = 0.487\nsamples = 110\nvalue = [46, 64]'),
#  Text(124.0, 101.92500000000001, 'Variance <= -3.889\ngini = 0.298\nsamples = 33\nvalue = [27, 6]'),
#  Text(62.0, 33.97500000000002, 'gini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(186.0, 33.97500000000002, 'gini = 0.071\nsamples = 27\nvalue = [26, 1]'),
#  Text(372.0, 101.92500000000001, 'Variance <= -0.084\ngini = 0.372\nsamples = 77\nvalue = [19, 58]'),
#  Text(310.0, 33.97500000000002, 'gini = 0.201\nsamples = 53\nvalue = [6, 47]'),
#  Text(434.0, 33.97500000000002, 'gini = 0.497\nsamples = 24\nvalue = [13, 11]'),
#  Text(558.0, 169.875, 'Curtosis <= -0.449\ngini = 0.3\nsamples = 98\nvalue = [80, 18]'),
#  Text(496.0, 101.92500000000001, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(620.0, 101.92500000000001, 'gini = 0.07\nsamples = 83\nvalue = [80, 3]'),
#  Text(527.0, 237.825, 'gini = 0.164\nsamples = 100\nvalue = [91, 9]'),
#  Text(713.0, 441.675, 'Curtosis <= -4.482\ngini = 0.169\nsamples = 290\nvalue = [263, 27]'),
#  Text(651.0, 373.725, 'Variance <= 9.347\ngini = 0.484\nsamples = 61\nvalue = [36, 25]'),
#  Text(589.0, 305.775, 'gini = 0.198\nsamples = 27\nvalue = [3, 24]'),
#  Text(713.0, 305.775, 'gini = 0.057\nsamples = 34\nvalue = [33, 1]'),
#  Text(775.0, 373.725, 'gini = 0.017\nsamples = 229\nvalue = [227, 2]')]

# %% [markdown]
# ##

# %%
dt = pd.read_csv("bill_authentication.csv")
dt
# Out:
#       Variance  Skewness  Curtosis  Entropy  Class
# 0      3.62160   8.66610   -2.8073 -0.44699      0
# 1      4.54590   8.16740   -2.4586 -1.46210      0
# 2      3.86600  -2.63830    1.9242  0.10645      0
# 3      3.45660   9.52280   -4.0112 -3.59440      0
# 4      0.32924  -4.45520    4.5718 -0.98880      0
# ...        ...       ...       ...      ...    ...
# 1367   0.40614   1.34920   -1.4501 -0.55949      1
# 1368  -1.38870  -4.87730    6.4774  0.34179      1
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1
# 1371  -2.54190  -0.65804    2.6842  1.19520      1
#
# [1372 rows x 5 columns]

# %%
X=dt.iloc[:,0:4].values
Y=dt.iloc[:,4].values

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size=0.2 , random_state= 0)

# %%
from sklearn.preprocessing import StandardScaler
sci= StandardScaler()
x_train=sci.fit_transform(x_train)
x_test=sci.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier
regresso=RandomForestClassifier(n_estimators=20,random_state= 0)
regresso.fit(x_train,y_train)
pre=regresso.predict(x_test)

# %%
print(classification_report(y_test,pre))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       157
#            1       0.98      0.99      0.99       118
#
#     accuracy                           0.99       275
#    macro avg       0.99      0.99      0.99       275
# weighted avg       0.99      0.99      0.99       275

# %%
confusion_matrix(y_test,pre)
# Out:
# array([[155,   2],
#        [  1, 117]], dtype=int64)

# %%
print('accuracy score :',accuracy_score(y_test,pre)*100)
# Out:
# accuracy score : 98.9090909090909
