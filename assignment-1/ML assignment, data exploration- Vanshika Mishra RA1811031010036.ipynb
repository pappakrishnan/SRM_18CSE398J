# %%
# %matplotlib inline

from numpy import arange
from matplotlib import pyplot as plt
from scipy.stats import norm
import pandas as pd

plt.rcParams['figure.figsize'] = [16, 7]

# %%
df=pd.read_csv('''StudentsPerformance.csv''')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.mean()
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %%
df.var()
# Out:
# math score       229.918998
# reading score    213.165605
# writing score    230.907992
# dtype: float64

# %%
df.skew()
# Out:
# math score      -0.278935
# reading score   -0.259105
# writing score   -0.289444
# dtype: float64

# %%
df.kurtosis()
# Out:
# math score       0.274964
# reading score   -0.068265
# writing score   -0.033365
# dtype: float64

# %%
df.min()
# Out:
# gender                                     female
# race/ethnicity                            group A
# parental level of education    associate's degree
# lunch                                free/reduced
# test preparation course                 completed
# math score                                      0
# reading score                                  17
# writing score                                  10
# dtype: object

# %%
df.max()
# Out:
# gender                                     male
# race/ethnicity                          group E
# parental level of education    some high school
# lunch                                  standard
# test preparation course                    none
# math score                                  100
# reading score                               100
# writing score                               100
# dtype: object

# %%
df.median()
# Out:
# math score       66.0
# reading score    70.0
# writing score    69.0
# dtype: float64

# %%
df.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr())

# %%
df.plot.scatter('math score','reading score',figsize=(10,7))

# %%
df.boxplot(figsize=(16, 5))

# %%
df['math score'].plot(figsize=(12, 5), color='black')

# %%
df['reading score'].plot(figsize=(12, 5), color='brown')

# %%
df['writing score'].plot(figsize=(12, 5), color='olive')

# %%
df['math score'].hist(bins=30, figsize=(8, 5));

# %%
df['writing score'].hist(bins=30, figsize=(8, 5));

# %%
df['reading score'].hist(bins=30, figsize=(8, 5));

# %%
df['math score'].hist(bins=30, figsize=(8, 5));
df['writing score'].hist(bins=30, figsize=(8, 5));
df['reading score'].hist(bins=30, figsize=(8, 5));
