# %%
# %matplotlib inline

from numpy import arange
from matplotlib import pyplot as plt
from scipy.stats import norm
import pandas as pd

plt.rcParams['figure.figsize'] = [20,10]

# %%
columns = ['COUNTRY','ISO3','WHO_REGION','DATA_SOURCE','DATE_UPDATED','TOTAL_VACCINATIONS','PERSONS_VACCINATED_1PLUS_DOSE','TOTAL_VACCINATIONS_PER100','PERSONS_VACCINATED_1PLUS_DOSE_PER100','PERSONS_FULLY_VACCINATED','PERSONS_FULLY_VACCINATED_PER100','VACCINES_USED','FIRST_VACCINE_DATE','NUMBER_VACCINES_TYPES_USED']

df = pd.read_csv('Vaccination_Data.csv')
df.columns = columns
df.head()
# Out:
#           COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0     Afghanistan  AFG       EMRO   REPORTING   2021-08-20
# 1         Albania  ALB       EURO        OWID   2021-08-17
# 2         Algeria  DZA       AFRO   REPORTING   2021-08-23
# 3  American Samoa  ASM       WPRO   REPORTING   2021-08-09
# 4         Andorra  AND       EURO        OWID   2021-08-15
#
#    TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0           1201286.0                       770542.0
# 1           1340339.0                       764997.0
# 2           4146091.0                      3421279.0
# 3             52769.0                        29210.0
# 4             91660.0                        51044.0
#
#    TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 0                      3.086                                 1.979
# 1                     46.575                                26.583
# 2                      9.455                                 7.802
# ...

# %%
df.tail()
# Out:
#                COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 222           Viet Nam  VNM       WPRO   REPORTING   2021-08-13
# 223  Wallis and Futuna  WLF       WPRO   REPORTING   2021-07-22
# 224              Yemen  YEM       EMRO   REPORTING   2021-07-27
# 225             Zambia  ZMB       AFRO   REPORTING   2021-08-23
# 226           Zimbabwe  ZWE       AFRO   REPORTING   2021-08-23
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 222           8061116.0                      7241093.0
# 223              9276.0                         4674.0
# 224            311483.0                       298161.0
# 225            503707.0                       303966.0
# 226           3772579.0                      2312417.0
#
#      TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 222                      8.282                                 7.439
# 223                     82.483                                41.561
# ...

# %%
df.dtypes
# Out:
# COUNTRY                                  object
# ISO3                                     object
# WHO_REGION                               object
# DATA_SOURCE                              object
# DATE_UPDATED                             object
# TOTAL_VACCINATIONS                      float64
# PERSONS_VACCINATED_1PLUS_DOSE           float64
# TOTAL_VACCINATIONS_PER100               float64
# PERSONS_VACCINATED_1PLUS_DOSE_PER100    float64
# PERSONS_FULLY_VACCINATED                float64
# PERSONS_FULLY_VACCINATED_PER100         float64
# VACCINES_USED                            object
# FIRST_VACCINE_DATE                       object
# NUMBER_VACCINES_TYPES_USED              float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   COUNTRY                               227 non-null    object
#  1   ISO3                                  227 non-null    object
#  2   WHO_REGION                            227 non-null    object
#  3   DATA_SOURCE                           227 non-null    object
#  4   DATE_UPDATED                          227 non-null    object
#  5   TOTAL_VACCINATIONS                    226 non-null    float64
#  6   PERSONS_VACCINATED_1PLUS_DOSE         218 non-null    float64
#  7   TOTAL_VACCINATIONS_PER100             226 non-null    float64
#  8   PERSONS_VACCINATED_1PLUS_DOSE_PER100  218 non-null    float64
#  9   PERSONS_FULLY_VACCINATED              216 non-null    float64
#  10  PERSONS_FULLY_VACCINATED_PER100       216 non-null    float64
# ...

# %%
df.memory_usage() # in bytes
# Out:
# Index                                    128
# COUNTRY                                 1816
# ISO3                                    1816
# WHO_REGION                              1816
# DATA_SOURCE                             1816
# DATE_UPDATED                            1816
# TOTAL_VACCINATIONS                      1816
# PERSONS_VACCINATED_1PLUS_DOSE           1816
# TOTAL_VACCINATIONS_PER100               1816
# PERSONS_VACCINATED_1PLUS_DOSE_PER100    1816
# PERSONS_FULLY_VACCINATED                1816
# PERSONS_FULLY_VACCINATED_PER100         1816
# VACCINES_USED                           1816
# FIRST_VACCINE_DATE                      1816
# NUMBER_VACCINES_TYPES_USED              1816
# dtype: int64

# %%
df.memory_usage().sum()
# Out:
# 25552

# %%
df.describe()
# Out:
#        TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# count        2.260000e+02                   2.180000e+02
# mean         2.044237e+07                   8.253955e+06
# std          1.268902e+08                   3.473510e+07
# min          7.300000e+01                   3.700000e+01
# 25%          9.987875e+04                   6.933075e+04
# 50%          8.988110e+05                   5.660505e+05
# 75%          6.258963e+06                   3.764875e+06
# max          1.776816e+09                   4.357201e+08
#
#        TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# count                 226.000000                            218.000000
# mean                   63.128195                             35.854991
# std                    51.608722                             26.885016
# min                     0.078000                              0.067000
# 25%                    13.012250                              9.629000
# ...

# %%
df.mean()
# Out:
# TOTAL_VACCINATIONS                      2.044237e+07
# PERSONS_VACCINATED_1PLUS_DOSE           8.253955e+06
# TOTAL_VACCINATIONS_PER100               6.312819e+01
# PERSONS_VACCINATED_1PLUS_DOSE_PER100    3.585499e+01
# PERSONS_FULLY_VACCINATED                4.889511e+06
# PERSONS_FULLY_VACCINATED_PER100         2.812897e+01
# NUMBER_VACCINES_TYPES_USED              3.219731e+00
# dtype: float64

# %%
df['NUMBER_VACCINES_TYPES_USED'].mean()
# Out:
# 3.219730941704036

# %%
df['PERSONS_FULLY_VACCINATED'].sum()
# Out:
# 1056134385.0

# %%
df.var()
# Out:
# TOTAL_VACCINATIONS                      1.610112e+16
# PERSONS_VACCINATED_1PLUS_DOSE           1.206527e+15
# TOTAL_VACCINATIONS_PER100               2.663460e+03
# PERSONS_VACCINATED_1PLUS_DOSE_PER100    7.228041e+02
# PERSONS_FULLY_VACCINATED                2.694942e+14
# PERSONS_FULLY_VACCINATED_PER100         6.370459e+02
# NUMBER_VACCINES_TYPES_USED              2.901951e+00
# dtype: float64

# %%
df.skew()
# Out:
# TOTAL_VACCINATIONS                      12.334141
# PERSONS_VACCINATED_1PLUS_DOSE            9.736706
# TOTAL_VACCINATIONS_PER100                0.441166
# PERSONS_VACCINATED_1PLUS_DOSE_PER100     0.226214
# PERSONS_FULLY_VACCINATED                 7.062170
# PERSONS_FULLY_VACCINATED_PER100          0.574913
# NUMBER_VACCINES_TYPES_USED               0.650929
# dtype: float64

# %%
df.kurtosis()
# Out:
# TOTAL_VACCINATIONS                      166.261644
# PERSONS_VACCINATED_1PLUS_DOSE           111.104264
# TOTAL_VACCINATIONS_PER100                -0.910117
# PERSONS_VACCINATED_1PLUS_DOSE_PER100     -1.150897
# PERSONS_FULLY_VACCINATED                 60.759231
# PERSONS_FULLY_VACCINATED_PER100          -0.757014
# NUMBER_VACCINES_TYPES_USED                0.204438
# dtype: float64

# %%
df['TOTAL_VACCINATIONS'].max()
# Out:
# 1776816416.0

# %%
df['TOTAL_VACCINATIONS'].min()
# Out:
# 73.0

# %%
df.min()
# Out:
# COUNTRY                                 Afghanistan
# ISO3                                            ABW
# WHO_REGION                                     AFRO
# DATA_SOURCE                                    OWID
# DATE_UPDATED                             2021-04-04
# TOTAL_VACCINATIONS                               73
# PERSONS_VACCINATED_1PLUS_DOSE                    37
# TOTAL_VACCINATIONS_PER100                     0.078
# PERSONS_VACCINATED_1PLUS_DOSE_PER100          0.067
# PERSONS_FULLY_VACCINATED                         36
# PERSONS_FULLY_VACCINATED_PER100               0.007
# NUMBER_VACCINES_TYPES_USED                        1
# dtype: object

# %%
df.max()
# Out:
# COUNTRY                                 occupied Palestinian territory
# ISO3                                                               ZWE
# WHO_REGION                                                        WPRO
# DATA_SOURCE                                                  REPORTING
# DATE_UPDATED                                                2021-08-23
# TOTAL_VACCINATIONS                                         1.77682e+09
# PERSONS_VACCINATED_1PLUS_DOSE                               4.3572e+08
# TOTAL_VACCINATIONS_PER100                                      233.208
# PERSONS_VACCINATED_1PLUS_DOSE_PER100                           116.933
# PERSONS_FULLY_VACCINATED                                   1.70139e+08
# PERSONS_FULLY_VACCINATED_PER100                                116.274
# NUMBER_VACCINES_TYPES_USED                                           9
# dtype: object

# %%
df.median()
# Out:
# TOTAL_VACCINATIONS                      898811.0000
# PERSONS_VACCINATED_1PLUS_DOSE           566050.5000
# TOTAL_VACCINATIONS_PER100                   53.3145
# PERSONS_VACCINATED_1PLUS_DOSE_PER100        32.5940
# PERSONS_FULLY_VACCINATED                324729.0000
# PERSONS_FULLY_VACCINATED_PER100             22.0230
# NUMBER_VACCINES_TYPES_USED                   3.0000
# dtype: float64

# %%
df.corr()
# Out:
#                                       TOTAL_VACCINATIONS  \
# TOTAL_VACCINATIONS                              1.000000
# PERSONS_VACCINATED_1PLUS_DOSE                   0.989262
# TOTAL_VACCINATIONS_PER100                       0.101607
# PERSONS_VACCINATED_1PLUS_DOSE_PER100            0.116021
# PERSONS_FULLY_VACCINATED                        0.936786
# PERSONS_FULLY_VACCINATED_PER100                 0.050727
# NUMBER_VACCINES_TYPES_USED                      0.160203
#
#                                       PERSONS_VACCINATED_1PLUS_DOSE  \
# TOTAL_VACCINATIONS                                         0.989262
# PERSONS_VACCINATED_1PLUS_DOSE                              1.000000
# TOTAL_VACCINATIONS_PER100                                  0.055327
# PERSONS_VACCINATED_1PLUS_DOSE_PER100                       0.087692
# PERSONS_FULLY_VACCINATED                                   0.876284
# PERSONS_FULLY_VACCINATED_PER100                            0.018861
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# Plotting with index along the x-axis
df['TOTAL_VACCINATIONS'].plot(figsize=(12, 5), color='black') # color and figsize changed

plt.xlim(0, 150) # range for x-axis
plt.ylim(0, 5000000) # range for x-axis
plt.xlabel('TOTAL_VACCINATIONS')
plt.ylabel('NUMBER_VACCINES_TYPES_USED'); # ";" prevents object info from displaying

# %%
# plotting one variable against the other
df.plot.scatter('PERSONS_VACCINATED_1PLUS_DOSE_PER100', 'PERSONS_FULLY_VACCINATED_PER100', figsize=(8, 5))

# The x and y labels are automatically taken from the column names
# Out:
# <AxesSubplot:xlabel='PERSONS_VACCINATED_1PLUS_DOSE_PER100', ylabel='PERSONS_FULLY_VACCINATED_PER100'>

# %%
# Box plot of a column
df['NUMBER_VACCINES_TYPES_USED'].plot.box(figsize=(8, 5));

# %%
# Box plot of all the columns with numerical data
df.boxplot(figsize=(20, 5)) # or df.plot.box()
# Out:
# <AxesSubplot:>

# %%
df['PERSONS_FULLY_VACCINATED_PER100'].hist(bins=30, figsize=(8, 8)); # we can specify the number of bins

# %%
ax = df['PERSONS_VACCINATED_1PLUS_DOSE_PER100'].hist(bins=30, grid=False, color='green', figsize=(10, 10)) # grid turned off and color changed

ax.set_xlabel('PERSONS_VACCINATED_1PLUS_DOSE_PER100')
ax.set_ylabel('PERSONS_FULLY_VACCINATED_PER100')

ax.set_xlim(0, 85) # limiting display range to 0-70 for the x-axis
ax.set_ylim(0, 50); # limiting display range to 0-120 for the y-axis

# %%
df_avg_BP = df.groupby('PERSONS_VACCINATED_1PLUS_DOSE_PER100')['PERSONS_FULLY_VACCINATED_PER100'].mean()
df_avg_BP[:10].plot.bar(color='red');

# %%
# To stack values from multiple columns
ax = df[['PERSONS_VACCINATED_1PLUS_DOSE_PER100', 'PERSONS_FULLY_VACCINATED_PER100']][:6].plot.bar(stacked=True)

ax.set_xlabel("Index")
ax.set_ylabel("Count");

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
# or fig, (ax1, ax2, ax3, ax4) = plt.subplots(2, 2, figsize=(12, 8))

# axes is the axes object(s). It can be a single object or an array of objects. 
# In this case, it is an array of dimension 2-by-2

df['PERSONS_VACCINATED_1PLUS_DOSE_PER100'].plot(ax = axes[0][0], style='.', color='red') # top left
df['PERSONS_FULLY_VACCINATED_PER100'].plot(ax = axes[0][1], style='.', color='blue') # top right

df['TOTAL_VACCINATIONS_PER100'].plot.hist(bins=30, ax = axes[1][0], color='black') # bottom left
df['NUMBER_VACCINES_TYPES_USED'].plot.hist(bins=20, ax = axes[1][1], color='gray') # bottom right

axes[0][0].set_xlabel('index')
axes[0][1].set_xlabel('index')
axes[1][0].set_xlabel('index')
axes[1][1].set_xlabel('index')


axes[0][0].set_ylim(20, 120)
axes[0][1].set_ylim(20, 240)

axes[1][0].set_xlim(0, 60)
axes[1][1].set_xlim(2, 8)

fig.tight_layout()
